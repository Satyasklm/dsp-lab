# %% [markdown]
# # Data Importing

# %%
import pandas as pd
df=pd.read_csv("sample.csv")
df
# Out:
#   NAME  AGE  SALARY GENDER DEPARTMENT
# 0  abc   21    1500      M        cse
# 1  def   18    1900      M        cse
# 2  fgh   20    1000      M        ece
# 3  ijk   25    2100      F        ece
# 4  xyz   19    2500      F        eee
# 5  wxy   24    1700      F       mech

# %%
print(df.loc[4])
# Out:
# NAME           xyz
# AGE             19
# SALARY        2500
# GENDER           F
# DEPARTMENT     eee
# Name: 4, dtype: object

# %%
print(df.loc[df["AGE"]>20])
# Out:
#   NAME  AGE  SALARY GENDER DEPARTMENT
# 0  abc   21    1500      M        cse
# 3  ijk   25    2100      F        ece
# 5  wxy   24    1700      F       mech

# %%
df['address']=["a","b","c","d","e","f"]

# %%
df
# Out:
#   NAME  AGE  SALARY GENDER DEPARTMENT address
# 0  abc   21    1500      M        cse       a
# 1  def   18    1900      M        cse       b
# 2  fgh   20    1000      M        ece       c
# 3  ijk   25    2100      F        ece       d
# 4  xyz   19    2500      F        eee       e
# 5  wxy   24    1700      F       mech       f

# %%
df["marks"]=0

# %%
df
# Out:
#   NAME  AGE  SALARY GENDER DEPARTMENT address  marks
# 0  abc   21    1500      M        cse       a      0
# 1  def   18    1900      M        cse       b      0
# 2  fgh   20    1000      M        ece       c      0
# 3  ijk   25    2100      F        ece       d      0
# 4  xyz   19    2500      F        eee       e      0
# 5  wxy   24    1700      F       mech       f      0

# %%
df.loc[1]
# Out:
# NAME           def
# AGE             18
# SALARY        1900
# GENDER           M
# DEPARTMENT     cse
# address          b
# marks            0
# Name: 1, dtype: object

# %%
df.loc[1,"NAME"]
# Out:
# 'def'

# %%
newdf=df[(df.AGE>15)&(df.SALARY>1500)]

# %%
newdf
# Out:
# Empty DataFrame
# Columns: [NAME, AGE, SALARY, GENDER, DEPARTMENT, address, marks]
# Index: []

# %%
newdf["NAME"]
# Out:
# 1    def
# 3    ijk
# 4    xyz
# 5    wxy
# Name: NAME, dtype: object

# %%
a=pd.read_csv("1000 Sales Records.csv")

# %%
a
# Out:
#                                 Region                           Country  \
# 0         Middle East and North Africa                             Libya
# 1                        North America                            Canada
# 2         Middle East and North Africa                             Libya
# 3                                 Asia                             Japan
# 4                   Sub-Saharan Africa                              Chad
# 5                               Europe                           Armenia
# 6                   Sub-Saharan Africa                           Eritrea
# 7                               Europe                        Montenegro
# 8    Central America and the Caribbean                           Jamaica
# 9                Australia and Oceania                              Fiji
# 10                  Sub-Saharan Africa                              Togo
# 11                              Europe                        Montenegro
# ...

# %%
a.to_excel("1000 Sales Records.xlsx",sheet_name="s1")

# %%
a=pd.read_excel("1000 Sales Records.xlsx")

# %%
a
# Out:
#      Unnamed: 0                             Region  \
# 0             0       Middle East and North Africa
# 1             1                      North America
# 2             2       Middle East and North Africa
# 3             3                               Asia
# 4             4                 Sub-Saharan Africa
# 5             5                             Europe
# 6             6                 Sub-Saharan Africa
# 7             7                             Europe
# 8             8  Central America and the Caribbean
# 9             9              Australia and Oceania
# 10           10                 Sub-Saharan Africa
# 11           11                             Europe
# 12           12                             Europe
# 13           13                 Sub-Saharan Africa
# 14           14                               Asia
# 15           15                             Europe
# 16           16                             Europe
# ...
